# %%
# === 1. Game State Logic ===
from copy import deepcopy
import pandas as pd
from collections import Counter
import os
import numpy as np
from multiprocessing import Pool

import math
import time
import random
import matplotlib.pyplot as plt

# Define the number of rows and columns for the game board
NUM_ROWS = 6
NUM_COLS = 7

class State:
    """
    Represents the state of the Connect Four game, including the game board, 
    available moves, current player, and winner status.
    """
    def __init__(self):
        # Initialize the game board as a 2D list filled with zeros (empty slots)
        self.board = [[0]*NUM_COLS for _ in range(NUM_ROWS)]
        # Track the current height of each column to determine where the next piece will land
        self.column_heights = [NUM_ROWS - 1] * NUM_COLS
        # List of available columns where a move can be made
        self.available_moves = list(range(7))
        # Player 1 starts the game
        self.player = 1
        # -1 indicates that the game is still ongoing, 0 indicates a draw
        self.winner = -1

    def check_line(self, n, player, values):
        """
        Check if a line contains the specified number of pieces (n) for a player.
        Also considers potential winning or strategic lines.
        """
        num_pieces = sum(val == player for val in values)
        if n == 4:
            return num_pieces == 4
        if n == 3:
            return num_pieces == 3 and values.count(0) == 1

    def count_lines(self, n, player):
        """
        Count the number of lines with n pieces for the specified player.
        Looks for horizontal, vertical, and diagonal lines.
        """
        num_lines = 0
        for row in range(NUM_ROWS):
            for col in range(NUM_COLS):
                # Horizontal
                if col < NUM_COLS - 3 and self.check_line(n, player, [self.board[row][col+i] for i in range(4)]):
                    num_lines += 1
                # Vertical
                if row < NUM_ROWS - 3 and self.check_line(n, player, [self.board[row+i][col] for i in range(4)]):
                    num_lines += 1
                # Diagonal (down-right)
                if row < NUM_ROWS - 3 and col < NUM_COLS - 3 and self.check_line(n, player, [self.board[row+i][col+i] for i in range(4)]):
                    num_lines += 1
                # Diagonal (down-left)
                if row < NUM_ROWS - 3 and col > 2 and self.check_line(n, player, [self.board[row+i][col-i] for i in range(4)]):
                    num_lines += 1
        return num_lines

    def move(self, column):
        """
        Simulate a move in the game by dropping a piece into a specified column.
        Returns a new state with the move applied.
        """
        state_copy = deepcopy(self)
        height = state_copy.column_heights[column]

        # Place the piece at the current available height
        state_copy.board[height][column] = self.player
        if height == 0:
            # Column is now full
            state_copy.available_moves.remove(column)
        else:
            # Decrease available height for this column
            state_copy.column_heights[column] = height - 1
        
        # Update winner status after move
        state_copy.update_winner()
        # Switch player
        state_copy.player = 3 - self.player

        return state_copy

    def update_winner(self):
        """
        Update the winner field based on the current board configuration.
        """
        if self.count_lines(4, 1) > 0:
            self.winner = 1
        elif self.count_lines(4, 2) > 0:
            self.winner = 2
        elif not self.available_moves:
            self.winner = 0  # draw

def column_features(state: State, col: int):
    """
    Features for dropping in column `col` from `state`:
      f0 = immediate win (1) or not (0)
      f1 = blocks opponent’s immediate win (1) or not (0)
      f2 = you get exactly 3 in a row (1) or not (0)
      f3 = opponent would get 3 in a row next if you DON’T play here
      f4 = is center column? (1 if col==3 else 0)
    """
    # simulate your move
    s2 = deepcopy(state).move(col)
    # immediate win?
    f0 = 1 if s2.winner == state.player else 0

    # blocks opponent win?
    f1 = 0
    if f0 == 0:  # no need if you already win
        for c2 in s2.available_moves:
            if s2.move(c2).winner == (3 - state.player):
                f1 = 1
                break

    # your 3-in-a-row count after playing
    f2 = 1 if state.count_lines(3, state.player) < s2.count_lines(3, state.player) else 0

    # opponent threat if you don’t play here
    f3 = 0
    # simulate opponent turn on original state
    for c2 in state.available_moves:
        if deepcopy(state).move(c2).winner == (3 - state.player):
            f3 = 1
            break

    # center bias
    f4 = 1 if col == NUM_COLS // 2 else 0

    return [f0, f1, f2, f3, f4]

def build_feature_dataset(match_data):
    """
    Given match logs (states and chosen moves), create a dataset of features and labels
    to train decision trees. Each record contains feature vectors for all 7 columns.
    """
    rows = []
    # for each logged (state, move) record
    for idx, rec in match_data.iterrows():
        # reconstruct state.board, state.player from rec['cell_0'..'cell_41'], rec['player']
        state = State()
        flat = [rec[f'cell_{i}'] for i in range(42)]
        for i, val in enumerate(flat):
            r, c = divmod(i, NUM_COLS)
            state.board[r][c] = val
        state.player = rec['player']
        # compute features for each legal move
        feats = []
        for col in state.available_moves:
            feats += column_features(state, col)
        # label is which index among available_moves was chosen
        label = state.available_moves.index(rec['mtcarlomove'])
        rows.append((feats, label))
    
    # Pad each row to have a consistent length (5 features * 7 columns)
    X, y = [], []
    for rec in rows:
        feat_vec, lbl = rec
        # pad to length 5*7
        if len(feat_vec) < 5*7:
            feat_vec += [0] * (5*7 - len(feat_vec))
        X.append(feat_vec)
        y.append(lbl)
    
    return pd.DataFrame(X, columns=[f'f{i}' for i in range(5*7)]), pd.Series(y)

# %%
# === 2. Game Interface ===

def display_board(board):
    """
    Exibe o tabuleiro no terminal de forma formatada.
    X representa o jogador 1, O representa o jogador 2, e espaços em branco são posições vazias.
    """
    print("\n  1 2 3 4 5 6 7")
    print(" ---------------")
    for row in board:
        print("|", end="")
        for cell in row:
            print(" ".join("X" if cell == 1 else "O" if cell == 2 else " "), end="|")
        print()
    print(" ---------------")

def print_welcome():
    """
    Imprime o menu principal do jogo com as opções disponíveis.
    """
    print("\n===== CONNECT 4 =====")
    print("1. Player vs Player")
    print("2. Player vs Computer")
    print("3. Computer vs Computer")
    print("4. Exit")
    print("====================")

# === Ensemble Training ===

def train_ensemble(match_data, n_trees: int = 7, max_depth: int = 7):
    """
    Treina um conjunto (ensemble) de árvores de decisão usando bootstrapping.
    
    Args:
        match_data (pd.DataFrame): Dados com estados e movimentos dos jogos anteriores.
        n_trees (int): Número de árvores a serem treinadas no ensemble.
        max_depth (int): Profundidade máxima de cada árvore.

    Returns:
        List[ID3DecisionTree]: Lista de árvores treinadas.
    """
    X, y = build_feature_dataset(match_data)
    ensemble = []
    N = len(X)
    for _ in range(n_trees):
        idx = np.random.choice(N, N, replace=True)  # amostragem com reposição
        Xt, yt = X.iloc[idx], y.iloc[idx]
        tree = ID3DecisionTree()
        tree.fit(Xt, yt, max_depth=max_depth)
        ensemble.append(tree)
    return ensemble

# === Ensemble Move Executor ===

def make_ensemble_ai(trees_list):
    """
    Cria uma função de IA baseada em um ensemble de árvores.
    Cada árvore vota em um índice da lista de `available_moves` e a maioria decide o movimento.

    Args:
        trees_list (List[ID3DecisionTree]): Conjunto de árvores de decisão.

    Returns:
        Callable[[ConnectFourGame], int]: Função que recebe o jogo e retorna a coluna a jogar.
    """
    def inner(game: ConnectFourGame):
        st = game.state
        feat = []
        # Gera vetores de características para cada coluna possível
        for col in range(NUM_COLS):
            if col in st.available_moves:
                feat += column_features(st, col)
            else:
                feat += [0]*5  # coluna não disponível recebe zeros
        row = pd.Series(feat, index=[f'f{i}' for i in range(5*NUM_COLS)])

        # Cada árvore faz uma previsão (índice na lista de colunas disponíveis)
        votes = [t.predict_one(row) for t in trees_list]
        try:
            # Voto da maioria
            best = Counter(votes).most_common(1)[0][0]
            # Garante que o voto esteja dentro do intervalo permitido
            if 0 <= best < len(st.available_moves):
                return st.available_moves[best]
            else:
                raise ValueError(f"Voted move index {best} is invalid for available moves {st.available_moves}")
        except Exception as e:
            # Em caso de erro, escolhe uma jogada aleatória como fallback
            print(f"⚠️ Ensemble fallback due to error: {e}")
            return random.choice(st.available_moves)

    return inner

# %%
# === 3. Learning from Logs ===

class DecisionNode:
    """
    Representa um nó em uma árvore de decisão. Pode ser um nó interno (com feature e filhos)
    ou um nó folha (com rótulo final).
    """
    def __init__(self, feature=None, children=None, label=None):
        self.feature = feature          # Nome da feature a ser testada neste nó
        self.children = children if children is not None else {}  # Dicionário de filhos: valor da feature → próximo nó
        self.label = label              # Rótulo se for folha (classe da previsão)

    def is_leaf(self):
        return self.label is not None   # Um nó é folha se tiver um label atribuído

class ID3DecisionTree:
    """
    Implementação do algoritmo ID3 para árvores de decisão.
    Utiliza entropia e ganho de informação para construir a árvore.
    """
    def __init__(self):
        self.tree = None  # Árvore final (raiz do modelo)

    def fit(self, X: pd.DataFrame, y: pd.Series, max_depth=None):
        """
        Treina a árvore de decisão com os dados fornecidos.
        
        Args:
            X (pd.DataFrame): Conjunto de entrada (features).
            y (pd.Series): Rótulos (movimentos realizados).
            max_depth (int): Profundidade máxima da árvore.
        """
        data = X.copy()
        data['label'] = y  # Adiciona a coluna alvo
        self.tree = self._id3(data, X.columns, depth=0, max_depth=max_depth)

    def _entropy(self, labels):
        """
        Calcula a entropia de um conjunto de rótulos.
        """
        counts = Counter(labels)
        total = len(labels)
        entropy = 0
        for count in counts.values():
            probability = count / total
            entropy -= probability * math.log2(probability)
        return entropy

    def _information_gain(self, data, feature, target_attribute='label'):
        """
        Calcula o ganho de informação ao dividir os dados com base em uma feature.
        """
        total_entropy = self._entropy(data[target_attribute])
        values = data[feature].unique()
        weighted_entropy = 0
        for value in values:
            subset = data[data[feature] == value]
            weighted_entropy += (len(subset) / len(data)) * self._entropy(subset[target_attribute])
        return total_entropy - weighted_entropy

    def _id3(self, data, features, depth=0, max_depth=None):
        """
        Algoritmo recursivo ID3 para construção da árvore.
        """
        labels = data['label']
        if len(set(labels)) == 1:
            # Todos os exemplos têm o mesmo rótulo → cria nó folha
            return DecisionNode(label=labels.iloc[0])
        if len(features) == 0 or (max_depth is not None and depth >= max_depth):
            # Não há mais features ou atingiu profundidade máxima → nó folha com rótulo mais comum
            return DecisionNode(label=labels.mode()[0])

        # Escolhe a melhor feature com base no ganho de informação
        gains = [(feature, self._information_gain(data, feature)) for feature in features]
        best_feature, _ = max(gains, key=lambda item: item[1])
        node = DecisionNode(feature=best_feature)

        # Cria filhos para cada valor possível da melhor feature
        for value in data[best_feature].unique():
            subset = data[data[best_feature] == value]
            if subset.empty:
                node.children[value] = DecisionNode(label=labels.mode()[0])  # fallback
            else:
                remaining_features = features.drop(best_feature)
                node.children[value] = self._id3(subset, remaining_features, depth + 1, max_depth)
        return node

    def predict_one(self, example, node=None):
        """
        Faz uma predição para uma única instância.
        """
        if node is None:
            node = self.tree
        if node.is_leaf():
            return node.label
        feature_value = example[node.feature]
        child = node.children.get(feature_value)
        if child is None:
            return None  # Caminho não conhecido
        return self.predict_one(example, child)

    def predict(self, X: pd.DataFrame):
        """
        Faz previsões para um conjunto de dados.
        """
        return X.apply(lambda row: self.predict_one(row), axis=1)

# === Initial Safe Training for Player 1 & Player 2 ===

# Árvores globais que armazenarão os ensembles aprendidos
learned_tree_p1 = None
learned_tree_p2 = None

def trainnn(p):
    """
    Realiza o treinamento inicial das árvores de decisão usando os dados do arquivo 'match_log.csv'.
    Cria ensembles separados para cada jogador.
    """
    try:
        md = pd.read_csv("match_log.csv")
        md = md[md['mtcarlomove'].notnull()]  # remove entradas sem jogada
        md.drop_duplicates(subset=[f'cell_{i}' for i in range(42)] + ['player'], inplace=True)
        # separa os dados por jogador
        data1 = md[md['player'] == 1]
        data2 = md[md['player'] == 2]

        if not data1.empty and p == 1:
            global learned_trees_p1
            learned_trees_p1 = train_ensemble(data1, n_trees=5, max_depth=5)
        if not data2.empty and p == 2:
            global learned_trees_p2
            learned_trees_p2 = train_ensemble(data2, n_trees=5, max_depth=5)
    except FileNotFoundError:
        print("🔸 No match_log.csv found; skipping training.")

# === Saving Logs in CSV file ===

def save_match_log(game_history, winner, file_path="match_log.csv"):
    """
    Salva o histórico de jogadas e o resultado de uma partida em um arquivo CSV.
    
    Args:
        game_history (list): Lista de tuplas (estado, jogada feita).
        winner (int): Jogador vencedor (1, 2 ou 0 para empate).
        file_path (str): Caminho do arquivo onde salvar os dados.
    """
    logs = []
    for state, best_move in game_history:
        # Converte o tabuleiro 2D em uma lista plana para armazenamento
        flat_board = sum(state.board, [])
        entry = {f'cell_{i}': val for i, val in enumerate(flat_board)}
        entry['player'] = state.player
        entry['mtcarlomove'] = best_move
        entry['winner'] = winner
        logs.append(entry)

    df = pd.DataFrame(logs)
    header_needed = not os.path.exists(file_path) or os.stat(file_path).st_size == 0
    df.to_csv(file_path, mode='a', header=header_needed, index=False)

# %%
# === 4. Game Controller Class ===
class ConnectFourGame:
    """
    Classe que gerencia o fluxo do jogo Connect Four.
    Controla os jogadores (IA ou humano), armazena logs de jogadas e executa partidas.
    """

    def __init__(self, player_1_ai, player_2_ai):
        # Estado inicial do jogo
        self.state = State()
        # Estratégia (função) para decidir o movimento de cada jogador
        self.player_1_ai = player_1_ai
        self.player_2_ai = player_2_ai
        # Lista de jogadas feitas durante a partida, usada para gerar logs
        self.match_log = []  # Lista de tuplas (estado, jogada)

    def record_play(self, state, move):
        """
        Registra um par (estado, jogada) no log para posterior aprendizado.
        Usa deepcopy para preservar o estado original.
        """
        self.match_log.append((deepcopy(state), move))

    def save_match_log(self, filename="match_log.csv"):
        """
        Salva o log da partida atual no arquivo CSV.
        """
        if not self.match_log:
            return
        save_match_log(self.match_log, winner=self.state.winner, file_path=filename)
        self.match_log = []

    def start(self, log_moves: bool = False):
        """
        Inicia uma partida entre dois jogadores (IA ou humanos).
        """
        self.state = State()           # Reinicia o estado do jogo
        self.match_log = []            # Reinicia o log da partida
        start_time = time.time()

        while self.state.winner == -1:  # Enquanto o jogo não terminou
            current_state = deepcopy(self.state)

            # Chama a função de IA correspondente ao jogador da vez
            if self.state.player == 1:
                move = self.player_1_ai(self)
            else:
                move = self.player_2_ai(self)

            self.record_play(current_state, move)  # Salva a jogada
            self.state = self.state.move(move)     # Aplica o movimento

            if log_moves:
                display_board(self.state.board)    # Mostra o tabuleiro atualizado

        # Mensagem final
        if self.state.winner == 0:
            print("End of game! Draw! %s seconds" % int(time.time() - start_time))
        else:
            print(f"End of game! Player {self.state.winner} wins in %s seconds!" % int(time.time() - start_time))

        self.save_match_log()  # Salva o log da partida

    def run_n_matches(self, n, max_time=3600, log_moves=True):
        """
        Roda várias partidas consecutivas entre os dois jogadores.
        
        Args:
            n (int): Número de partidas.
            max_time (int): Tempo máximo total (em segundos).
            log_moves (bool): Exibe o tabuleiro a cada jogada.
        """
        start_time = time.time()
        results = [0, 0, 0]  # Índices: 0 = empate, 1 = vitórias do jogador 1, 2 = vitórias do jogador 2
        total_games = n

        while n > 0 and time.time() - start_time < max_time:
            n -= 1
            self.start(log_moves)
            results[self.state.winner] += 1  # Atualiza contagem de vitórias/empates

            # Salva estatísticas de desempenho
            game_number = total_games - n
            with open("performance_log.csv", "a") as f:
                f.write(f"{game_number},{self.state.winner}\n")

            # Treinamento incremental baseado no log
            try:
                match_data = pd.read_csv("match_log.csv")
                match_data = match_data[match_data['mtcarlomove'].notnull()]
                match_data.drop_duplicates(subset=[f'cell_{i}' for i in range(42)] + ['player'], inplace=True)
                X = match_data[[f'cell_{i}' for i in range(42)] + ['player']]
                y = match_data['mtcarlomove']

                if len(X) == 0 or y.nunique() < 2:
                    print("⚠️ Dados insuficientes para treinar. Pulando treino.")
                    continue

                # Treina árvore para o jogador que irá jogar na próxima partida
                if self.state.player == 1:
                    learned_tree_p1 = ID3DecisionTree()
                    learned_tree_p1.fit(X, y, max_depth=3)
                else:
                    learned_tree_p2 = ID3DecisionTree()
                    learned_tree_p2.fit(X, y, max_depth=3)

            except FileNotFoundError:
                print("⚠️ match_log.csv not found. AI will only be trained after the first matches.")
                continue

        # Exibe resumo após os jogos
        print("\n=== Elapsed time: %s seconds ===" % int(time.time() - start_time))
        print(f"  Player 1: {results[1]} victories")
        print(f"  Player 2: {results[2]} victories")
        print(f"  Draws: {results[0]}")
        print("===============================")

# %%
# === 5. Human & AI Players Moves ===

def human_player_move(game):
    """
    Função que recebe a jogada do jogador humano via input no terminal.
    Garante que a jogada seja válida antes de retorná-la.
    """
    while True:
        try:
            print(f"\nPlayer {game.state.player}'s turn")
            print(f"Available columns: {[col+1 for col in game.state.available_moves]}")
            column = int(input("Enter column number (1-7): ")) - 1  # Converte para índice de 0 a 6
            if column in game.state.available_moves:
                return column  # Retorna a jogada escolhida (índice da coluna)
            else:
                print("Invalid move! Try again.")
        except ValueError:
            print("Please enter a valid number.")

def execute_random_move(game):
    """
    Função para IA aleatória.
    Escolhe e retorna uma jogada válida aleatoriamente entre as disponíveis.
    """
    move = random.choice(game.state.available_moves)
    return move

# === Execução da IA aprendida ===
def execute_learned_move(tree):
    """
    Cria uma função de IA baseada em uma árvore de decisão única treinada.
    A árvore prevê um índice na lista de colunas disponíveis (available_moves).

    Args:
        tree (ID3DecisionTree): Árvore de decisão treinada.

    Returns:
        Callable[[ConnectFourGame], int]: Função que recebe o jogo e retorna a coluna a jogar.
    """
    def inner(game: ConnectFourGame):
        st = game.state
        feat = []

        # Gera vetor de características considerando as 7 colunas (5 features cada)
        for col in range(NUM_COLS):
            if col in st.available_moves:
                feat += column_features(st, col)
            else:
                feat += [0]*5  # colunas indisponíveis são preenchidas com zeros

        row = pd.Series(feat, index=[f'f{i}' for i in range(5 * NUM_COLS)])

        try:
            pred = tree.predict_one(row)

            # Garante que o índice previsto está dentro da lista de colunas disponíveis
            if pred is None:
                raise ValueError("Previsão da árvore foi None.")
            if 0 <= pred < len(st.available_moves):
                return st.available_moves[pred]
            else:
                raise ValueError(f"Previsão inválida: {pred} para available_moves: {st.available_moves}")
        except Exception as e:
            print(f"⚠️ Fallback para jogada aleatória (erro na IA): {e}")
            return random.choice(st.available_moves)

    return inner

# %%
# === 6. Monte Carlo Tree Search ===
class MCNode:
    """
    Representa um estado do jogo e armazena estatísticas para as simulações de MCTS.
    """
    def __init__(self, state: State, player: int):
        self.state   = state           # Estado atual do jogo
        self.player  = player          # Jogador que iniciou neste nó
        self.wins    = 0               # Número de vitórias simuladas
        self.visits  = 0               # Número de vezes que o nó foi visitado
        self.children = []            # Filhos gerados a partir deste estado
        self.is_terminal = (state.winner != -1)  # Se já é fim de jogo

    def is_leaf(self):
        return len(self.children) == 0

    def add_child(self, player):
        """
        Expande o nó gerando filhos para todas as jogadas possíveis.
        """
        if self.is_terminal:
            return None  # Nó terminal não pode ser expandido
        for move in self.state.available_moves:
            new_state = self.state.move(move)
            self.children.append(MCNode(new_state, player))
        return random.choice(self.children)  # Retorna um filho aleatório

    def update_stats(self, value):
        """
        Atualiza as estatísticas de vitórias e visitas com base no resultado da simulação.
        """
        if self.player == value:
            reward = 1
        elif value == 0:
            reward = 0  # empate
        else:
            reward = 0  # derrota
        self.wins += reward
        self.visits += 1

class MCTree:
    """
    Representa a árvore de busca de Monte Carlo com um nó raiz.
    """
    def __init__(self, root):
        self.root = root

    def expand(self, node, player_cur):
        return node.add_child(player_cur)

def monte_carlo(epochs, tree, c, player):
    """
    Executa a simulação MCTS por um número de épocas.
    """
    for _ in range(epochs):
        visited = []
        player_cur = player
        node = tree.root
        visited.append(node)

        # Seleção: navega até folha ou nó terminal
        while not node.is_leaf() and not node.is_terminal:
            node = select(node, node.children, c, player_cur)
            visited.append(node)
            player_cur = 3 - player_cur  # alterna o jogador

        # Expansão
        new_child = tree.expand(node, player_cur)
        if new_child is not None and not new_child.is_terminal:
            visited.append(new_child)
            value = roll_out(new_child)  # Simulação
        else:
            value = node.state.winner if node.is_terminal else roll_out(node)

        # Retropropagação
        for n in visited:
            n.update_stats(value)

    return best_action(tree.root)

def mcts_worker(args):
    """
    Executa uma MCTS parcial para ser usada em paralelo.
    """
    (root_state, epochs, c, player) = args
    tree = MCTree(MCNode(deepcopy(root_state), player))
    monte_carlo(epochs, tree, c, player)
    stats = [(child.wins, child.visits) for child in tree.root.children]
    return stats

def execute_monte_carlo_move_parallel(epochs, c, player, workers=4):
    """
    Retorna uma função de jogada usando MCTS em paralelo com múltiplos workers.
    """
    def inner(game: ConnectFourGame):
        root_state = game.state
        root = MCNode(deepcopy(root_state), player)

        # Pré-expansão da raiz para garantir ordem consistente de filhos
        for mv in root_state.available_moves:
            root.children.append(MCNode(root_state.move(mv), 3-player))

        per_worker = epochs // workers
        args = [(root_state, per_worker, c, player) for _ in range(workers)]

        with Pool(workers) as pool:
            results = pool.map(mcts_worker, args)

        # Agrega resultados de todos os workers
        num_moves = len(root.children)
        agg_wins   = [0.0]*num_moves
        agg_visits = [0]*num_moves
        for stats in results:
            for i, (w,v) in enumerate(stats):
                agg_wins[i]   += w
                agg_visits[i] += v

        # Escolhe o filho com maior taxa de vitória
        best_idx = max(
            range(num_moves),
            key=lambda i: (agg_wins[i]/agg_visits[i]) if agg_visits[i] > 0 else -1
        )
        best_child = root.children[best_idx]

        # Identifica qual coluna foi jogada para chegar no estado do melhor filho
        for col in range(NUM_COLS):
            if root_state.column_heights[col] != best_child.state.column_heights[col]:
                return col
        return random.choice(root_state.available_moves)  # fallback se falhar

    return inner

def select(node, children, c, player):
    """
    Função de seleção baseada no valor UCT.
    """
    for child in children:
        if child.visits == 0:
            return child  # Explora filhos não visitados

    best_value = -math.inf
    best_node  = None
    ln_parent  = math.log(node.visits)

    for child in children:
        uct = (child.wins / child.visits) + c * math.sqrt(ln_parent / child.visits)
        if uct > best_value:
            best_value, best_node = uct, child
    return best_node

def best_action(root):
    """
    Escolhe a melhor ação com base na maior taxa de vitórias.
    """
    return max(root.children, key=lambda child: child.wins / child.visits)

def roll_out(node):
    """
    Simula uma partida aleatória a partir de um nó até o final do jogo.
    """
    sim_state = deepcopy(node.state)
    while sim_state.winner == -1:
        move = random.choice(sim_state.available_moves)
        sim_state = sim_state.move(move)
    return sim_state.winner

def execute_monte_carlo_move(epochs, c, player):
    """
    Retorna uma função de jogada usando MCTS sequencial.
    """
    def inner(game: ConnectFourGame):
        root = MCNode(deepcopy(game.state), 3 - player)
        best_node = monte_carlo(epochs, MCTree(root), c, player)

        # Identifica qual foi a jogada realizada
        for col in range(NUM_COLS):
            if game.state.column_heights[col] != best_node.state.column_heights[col]:
                return col
        return random.choice(game.state.available_moves)  # fallback

    return inner

# %%
# === 7. Main Game Loop ===

if __name__ == "__main__":
    while True:
        print_welcome()
        choice = input("Select game mode: ")

        # Modo 1: Humano vs Humano
        if choice == "1":
            game = ConnectFourGame(human_player_move, human_player_move)
            game.start(log_moves=True)

        # Modo 2: Humano vs IA
        elif choice == "2":
            player_choice = input("Play as Player 1 (X) or Player 2 (O)? (1/2): ")
            # Determina se a IA será o jogador 1 ou 2
            ai_player = 2 if player_choice == "1" else 1
            if player_choice == "1":
                game = ConnectFourGame(human_player_move, choose_ai(2))
            else:
                game = ConnectFourGame(choose_ai(1), human_player_move)

            game.start(log_moves=True)


        # Modo 3: IA vs IA
        elif choice == "3":
            print("\nChoose AI for Player 1 and Player 2:")
            print("1. Random")
            print("2. Learned Decision Tree")
            print("3. Monte Carlo Tree Search (MCTS)")
            print("4. Monte Carlo Tree Search Parallel(MCTS)")
            print("5. Learned Decision Tree (ensemble vote)")

            # Função para o usuário escolher a IA de cada jogador
            def choose_ai(player_num):
                choice = input(f"Choose AI for Player {player_num} (1/2/3/4/5): ")
                if choice == "1":
                    return execute_random_move
                elif choice == "2":
                    trainnn(player_num)
                    learned_trees = {1: learned_trees_p1, 2: learned_trees_p2}
                    ai = learned_trees[player_num]
                    return execute_learned_move(ai[3])
                elif choice == "3":
                    n = int(input(f"Chosse epochs for mtcarlo: "))
                    return execute_monte_carlo_move(epochs=n, c=1.14, player=player_num)
                elif choice == "4":
                    n = int(input(f"Chosse epochs for mtcarlo: "))
                    return execute_monte_carlo_move_parallel(epochs=n, c=1.14, player=player_num)
                elif choice == "5":
                    trainnn(player_num)
                    learned_trees = {1: learned_trees_p1, 2: learned_trees_p2}
                    ai = learned_trees[player_num]
                    return make_ensemble_ai(ai)
                else:
                    print("⚠️ Invalid choice. Defaulting to Random.")
                    return execute_random_move

            # Configura os dois jogadores
            ai1 = choose_ai(1)
            ai2 = choose_ai(2)
            game = ConnectFourGame(ai1, ai2)
            num_games = int(input("How many games to run? "))
            game.run_n_matches(num_games, log_moves=True)

        # Sair do jogo
        elif choice == "4":
            print("Thanks for playing!")
            break

        else:
            print("Invalid choice. Try again.")
# Out:
# ===== CONNECT 4 =====
# 1. Player vs Player
# 2. Player vs Computer
# 3. Computer vs Computer
# 4. Exit
# ====================
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 24
#      21 else:
#      22     game = ConnectFourGame(learned_ai, human_player_move)
# ---> 24 game.start(log_moves=True)
#      26 # Reentreina apenas a árvore de decisão da IA com os dados do jogo atual
#      27 match_data = pd.read_csv("match_log.csv")
#
# Cell In[53], line 51, in ConnectFourGame.start(self, log_moves)
#      48     move = self.player_2_ai(self)
#      50 self.record_play(current_state, move)  # Salva a jogada
# ---> 51 self.state = self.state.move(move)     # Aplica o movimento
#      53 if log_moves:
#      54     display_board(self.state.board)    # Mostra o tabuleiro atualizado
#
# Cell In[50], line 74, in State.move(self, column)
#      69 """
#      70 Simulate a move in the game by dropping a piece into a specified column.
#      71 Returns a new state with the move applied.
#      72 """
#      73 state_copy = deepcopy(self)
# ---> 74 height = state_copy.column_heights[column]
#      76 # Place the piece at the current available height
#      77 state_copy.board[height][column] = self.player
#
# TypeError: list indices must be integers or slices, not function

# %%
def analyze_performance(file_path='performance_log.csv', batch_size=100):
    # Verifica se o arquivo existe
    if not os.path.exists(file_path):
        print(f"Arquivo {file_path} não encontrado.")
        return

    # Carregar os dados do log de desempenho
    data = pd.read_csv(file_path, header=None, names=['game', 'winner'])

    # Agrupar os jogos em lotes (batches) com base no tamanho definido
    data['batch'] = data.index // batch_size

    # Calcular a taxa de vitória do jogador 1 para cada lote
    batch_stats = data.groupby('batch')['winner'].apply(lambda x: (x == 1).mean())
    print(batch_size ,batch_stats)

    # Plotar gráfico com a taxa de vitória ao longo do tempo
    plt.figure(figsize=(12, 6))
    plt.plot(batch_stats.index + 1, batch_stats.values, marker='o', linestyle='-', color='blue', label='Win Rate of Player 1')
    plt.axhline(y=0.5, color='red', linestyle='--', label='50% Baseline')  # Linha de base 50%
    plt.xlabel(f'Batch Number ({batch_size} games per batch)')  # Eixo X: número do lote
    plt.ylabel('Win Rate of Player 1')                          # Eixo Y: taxa de vitórias
    plt.title(f'Win Rate of Player 1 Over Time (Batches of {batch_size} Games)')  # Título
    plt.legend()
    plt.grid(alpha=0.3)
    plt.xticks(range(1, len(batch_stats) + 1))
    plt.tight_layout()
    plt.show()

# Permite que o gráfico seja gerado automaticamente se o script for executado diretamente
if __name__ == "__main__":
    analyze_performance()
# Out:
# 100 batch
# 0    0.90
# 1    0.86
# 2    0.29
# Name: winner, dtype: float64
